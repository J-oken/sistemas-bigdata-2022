# %% [markdown]
# # Práctica SQL en Database Employees

# %% [markdown]
# Asegúrate de que tes acceso a un servidor de mysql/mariadb no que estea instalada a base de datos de exemplo: employees

# %%
# Instalación de librarías
# ipython-sql

# %%
# load the ipython-sql extension
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 2
#       1 # load the ipython-sql extension
# ----> 2 get_ipython().run_line_magic('load_ext', 'sql')
#
# File ~/anaconda3/envs/sistemas/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/anaconda3/envs/sistemas/lib/python3.8/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File ~/anaconda3/envs/sistemas/lib/python3.8/site-packages/IPython/core/extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File ~/anaconda3/envs/sistemas/lib/python3.8/site-packages/IPython/core/extensions.py:91, in ExtensionManager._load_extension(self, module_str)
#      89 with self.shell.builtin_trap:
#      90     if module_str not in sys.modules:
# ---> 91         mod = import_module(module_str)
#      92     mod = sys.modules[module_str]
#      93     if self._call_load_ipython_extension(mod):
#
# File ~/anaconda3/envs/sistemas/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:973, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sql'

# %% [markdown]
# Define o nome de usuario e o enderezo do servidor web. Ollo ao prompt cando che pide o contrasinal.

# %%
import getpass
# define user & password
user = 'nome_usuario'
password = getpass.getpass()   # ollo ao contrasinal cando o pida
connection_string = f'mysql+pymysql://{user}:{password}@localhost:3306/employees'
# %sql $connection_string
# Out:
#  ··················
# 'Connected: miguel@employees'

# %%
import getpass
# define user & password
user = 'user'
password = getpass.getpass()   # ollo ao contrasinal cando o pida
connection_string = f'mysql+pymysql://{user}:{password}@192.168.33.20:3306/employees'
# %sql $connection_string
# Out:
#  ··················
# 'Connected: miguel@employees'

# %% [markdown]
# The configuration cell below is to simply limit the output to 10 rows.

# %%
# fixamos o límite a 10 liñas default á hora de mostrar os resultados
# %config SqlMagic.displaylimit=10

# %% [markdown]
# ## Employees Database Schema

# %% [markdown]
# ![schema](https://dev.mysql.com/doc/employee/en/images/employees-schema.png)

# %%
# Seleccionar todos os empregados
# %%sql
SELECT * FROM employees;
# Out:
#   File "<ipython-input-3-0a5e62b04540>", line 3
#     SELECT * FROM employees;
#                   ^
# SyntaxError: invalid syntax

# %%
# Mostrar nomes completos dos empregados
# %%sql
SELECT CONCAT(first_name, ' ', last_name) AS emp_name
FROM employees;
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 300024 rows affected.
# [('Georgi Facello',),
#  ('Bezalel Simmel',),
#  ('Parto Bamford',),
#  ('Chirstian Koblick',),
#  ('Kyoichi Maliniak',),
#  ('Anneke Preusig',),
#  ('Tzvetan Zielinski',),
#  ('Saniya Kalloufi',),
#  ('Sumant Peac',),
#  ('Duangkaew Piveteau',),
#  ('Mary Sluis',),
#  ('Patricio Bridgland',),
#  ('Eberhardt Terkki',),
#  ('Berni Genin',),
#  ('Guoxiang Nooteboom',),
#  ('Kazuhito Cappelletti',),
#  ('Cristinel Bouloucos',),
#  ('Kazuhide Peha',),
#  ('Lillian Haddadi',),
#  ('Mayuko Warwick',),
#  ('Ramzi Erde',),
#  ('Shahaf Famili',),
#  ('Bojan Montemayor',),
#  ('Suzette Pettey',),
#  ('Prasadram Heyers',),
#  ('Yongqiao Berztiss',),
#  ('Divier Reistad',),
#  ('Domenick Tempesti',),
#  ('Otmar Herbst',),
#  ('Elvis Demeyer',),
#  ('Karsten Joslin',),
#  ('Jeong Reistad',),
#  ('Arif Merlo',),
#  ('Bader Swan',),
#  ('Alain Chappelet',),
#  ('Adamantios Portugali',),
#  ('Pradeep Makrucki',),
#  ('Huan Lortz',),
#  ('Alejandro Brender',),
#  ('Weiyi Meriste',),
#  ('Uri Lenart',),
#  ('Magy Stamatiou',),
#  ('Yishay Tzvieli',),
#  ('Mingsen Casley',),
#  ('Moss Shanbhogue',),
#  ('Lucien Rosenbaum',),
#  ('Zvonko Nyanchama',),
#  ('Florian Syrotiuk',),
#  ('Basil Tramer',),
#  ('Yinghua Dredge',),
#  ('Hidefumi Caine',),
#  ('Heping Nitsch',),
#  ('Sanjiv Zschoche',),
#  ('Mayumi Schueller',),
#  ('Georgy Dredge',),
#  ('Brendon Bernini',),
#  ('Ebbe Callaway',),
#  ('Berhard McFarlin',),
#  ('Alejandro McAlpine',),
#  ('Breannda Billingsley',),
#  ('Tse Herber',),
#  ('Anoosh Peyn',),
#  ('Gino Leonhardt',),
#  ('Udi Jansch',),
#  ('Satosi Awdeh',),
#  ('Kwee Schusler',),
#  ('Claudi Stavenow',),
#  ('Charlene Brattka',),
#  ('Margareta Bierman',),
#  ('Reuven Garigliano',),
#  ('Hisao Lipner',),
#  ('Hironoby Sidou',),
#  ('Shir McClurg',),
#  ('Mokhtar Bernatsky',),
#  ('Gao Dolinsky',),
#  ('Erez Ritzmann',),
#  ('Mona Azuma',),
#  ('Danel Mondadori',),
#  ('Kshitij Gils',),
#  ('Premal Baek',),
#  ('Zhongwei Rosen',),
#  ('Parviz Lortz',),
#  ('Vishv Zockler',),
#  ('Tuval Kalloufi',),
#  ('Kenroku Malabarba',),
#  ('Somnath Foote',),
#  ('Xinglin Eugenio',),
#  ('Jungsoon Syrzycki',),
#  ('Sudharsan Flasterstein',),
#  ('Kendra Hofting',),
#  ('Amabile Gomatam',),
#  ('Valdiodio Niizuma',),
#  ('Sailaja Desikan',),
#  ('Arumugam Ossenbruggen',),
#  ('Hilari Morton',),
#  ('Jayson Mandell',),
#  ('Remzi Waschkowski',),
#  ('Sreekrishna Servieres',),
#  ('Valter Sullins',),
#  ('Hironobu Haraldson',),
#  ('Perla Heyers',),
#  ('Paraskevi Luby',),
#  ('Akemi Birch',),
#  ('Xinyu Warwick',),
#  ('Hironoby Piveteau',),
#  ('Eben Aingworth',),
#  ('Dung Baca',),
#  ('Lunjin Giveon',),
#  ('Mariusz Prampolini',),
#  ('Xuejia Ullian',),
#  ('Hugo Rosis',),
#  ('Yuichiro Swick',),
#  ('Jaewon Syrzycki',),
#  ('Munir Demeyer',),
#  ('Chikara Rissland',),
#  ('Dayanand Czap',),
#  ('Kiyotoshi Blokdijk',),
#  ('Zhonghui Zyda',),
#  ('Domenick Peltason',),
#  ('Armond Fairtlough',),
#  ('Guoxiang Ramsay',),
#  ('Ohad Esposito',),
#  ('Hinrich Randi',),
#  ('Geraldo Marwedel',),
#  ('Syozo Hiltgen',),
#  ('Kayoko Valtorta',),
#  ('Subir Baja',),
#  ('Babette Lamba',),
#  ('Armond Peir',),
#  ('Nishit Casperson',),
#  ('Magdalena Eldridge',),
#  ('Ayakannu Skrikant',),
#  ('Giri Isaak',),
#  ('Diederik Siprelle',),
#  ('Nathan Monkewich',),
#  ('Zissis Pintelas',),
#  ('Maren Hutton',),
#  ('Perry Shimshoni',),
#  ('Ewing Foong',),
#  ('Yucel Auria',),
#  ('Shahaf Ishibashi',),
#  ('Tzvetan Hettesheimer',),
#  ('Sakthirel Bakhtari',),
#  ('Marla Brendel',),
#  ('Akemi Esposito',),
#  ('Chenyi Syang',),
#  ('Kazuhito Encarnacion',),
#  ('Douadi Azumi',),
#  ('Xiadong Perry',),
#  ('Zhenbing Perng',),
#  ('Itzchak Lichtner',),
#  ('Jaques Munro',),
#  ('Heekeun Majewski',),
#  ('Abdulah Thibadeau',),
#  ('Adas Nastansky',),
#  ('Sumali Fargier',),
#  ('Nigel Aloisi',),
#  ('Khedija Mitsuhashi',),
#  ('Serif Buescher',),
#  ('Debatosh Khasidashvili',),
#  ('Hairong Mellouli',),
#  ('Florina Eugenio',),
#  ('Karsten Szmurlo',),
#  ('Jagoda Braunmuhl',),
#  ('Miyeon Macedo',),
#  ('Samphel Siegrist',),
#  ('Duangkaew Rassart',),
#  ('Dharmaraja Stassinopoulos',),
#  ('Sampalli Snedden',),
#  ('Kasturi Jenevein',),
#  ('Herbert Trachtenberg',),
#  ('Shigeu Matzen',),
#  ('Shrikanth Mahmud',),
#  ('Badri Furudate',),
#  ('Aleksandar Ananiadou',),
#  ('Brendon Lenart',),
#  ('Pragnesh Iisaka',),
#  ('Valery Litvinov',),
#  ('Deniz Duclos',),
#  ('Shaw Wendorf',),
#  ('Sibyl Nooteboom',),
#  ('Moriyoshi Merey',),
#  ('Mechthild Bonifati',),
#  ('Mihalis Lowrie',),
#  ('Duro Sidhu',),
#  ('Shigehito Kropatsch',),
#  ('Tommaso Narwekar',),
#  ('Christ Muchinsky',),
#  ('Khalid Erva',),
#  ('Arve Fairtlough',),
#  ('Zdislav Nastansky',),
#  ('Mohua Falck',),
#  ('Masaru Cheshire',),
#  ('Josyula Hofmeyr',),
#  ('Annemarie Redmiles',),
#  ('Marc Hellwagner',),
#  ('Kasidit Krzyzanowski',),
#  ('Pranav Furedi',),
#  ('Kazuhisa Ranta',),
#  ('Vidya Awdeh',),
#  ('Idoia Kavraki',),
#  ('Greger Lichtner',),
#  ('Steen Escriba',),
#  ('Nevio Ritcey',),
#  ('Mabhin Leijenhorst',),
#  ('Alassane Iwayama',),
#  ('Girolamo Anandan',),
#  ('Xiping Klerer',),
#  ('Yolla Ellozy',),
#  ('Yuping Alpin',),
#  ('Vishu Strehl',),
#  ('Divier Esteva',),
#  ('Jackson Kakkad',),
#  ('Tadahiko Ciolek',),
#  ('Xiaobin Duclos',),
#  ('Amstein Ghemri',),
#  ('Yongmin Roison',),
#  ('Zhenhua Magalhaes',),
#  ('Genta Kolvik',),
#  ('Kish Fasbender',),
#  ('Yucai Granlund',),
#  ('Tze Nourani',),
#  ('Carrsten Schmiedel',),
#  ('Leon Trogemann',),
#  ('Kellie Chinen',),
#  ('Xinglin Plessier',),
#  ('Anneli Kaiser',),
#  ('Karoline Cesareni',),
#  ('Ulises Takanami',),
#  ('Clyde Vernadat',),
#  ('Shaowen Desikan',),
#  ('Marko Auria',),
#  ('Lein Vendrig',),
#  ('Arunachalam Bakhtari',),
#  ('Susanta Roccetti',),
#  ('Susumu Bade',),
#  ('Yannis Mandell',),
#  ('Mototsugu Gire',),
#  ('Nikolaos Llado',),
#  ('Remko Maccarone',),
#  ('Ortrud Murillo',),
#  ('Lunjin Ozeri',),
#  ('Wonhee Pouyioutas',),
#  ('Foong Flasterstein',),
#  ('Ramalingam Gente',),
#  ('Basem Teitelbaum',),
#  ('Heon Riefers',),
#  ('Frederique Tempesti',),
#  ('Marie Boreale',),
#  ('Serap Etalle',),
#  ('Alair Rosenbaum',),
#  ('Shirish Wegerle',),
#  ('Zsolt Salinas',),
#  ('Shen Brattka',),
#  ('Roddy Garnick',),
#  ('Irene Radhakrishnan',),
#  ('Aiman Riexinger',),
#  ('Basil Ishibashi',),
#  ('Susanna Vesel',),
#  ('Alper Suomi',),
#  ('Mang Erie',),
#  ('Mahendra Maraist',),
#  ('Takahiro Waterhouse',),
#  ('Nalini Kawashimo',),
#  ('Ramalingam Muniz',),
#  ('Sukumar Rassart',),
#  ('Shaunak Cullers',),
#  ('Nishit Siochi',),
#  ('Taizo Oxman',),
#  ('Bedir Hartvigsen',),
#  ('Sham Eastman',),
#  ('Yishai Cannane',),
#  ('Baocai Lieblein',),
#  ('Dmitri Pearson',),
#  ('Marek Luck',),
#  ('Xuejun Hempstead',),
#  ('Isaac Schwartzbauer',),
#  ('Lubomir Nitsch',),
#  ('Barton Jumpertz',),
#  ('Stabislas Delgrange',),
#  ('Moty Kusakari',),
#  ('Hercules Benzmuller',),
#  ('Kauko Birjandi',),
#  ('Masali Murrill',),
#  ('Zhonghui Preusig',),
#  ('Saddek Gopalakrishnan',),
#  ('Marie Pietracaprina',),
#  ('Selwyn Perri',),
#  ('Shay Poulakidas',),
#  ('Yongmao Pleszkun',),
#  ('Dipayan Seghrouchni',),
#  ('Yucel Ghelli',),
#  ('Mihalis Avouris',),
#  ('Rutger Miara',),
#  ('Kristine Velardi',),
#  ('Petter Lorho',),
#  ('Narain Oaver',),
#  ('Dietrich DuCasse',),
#  ('Ipke Stentiford',),
#  ('Tadahiko Ulupinar',),
#  ('Lucien Staudhammer',),
#  ('Faiza Baer',),
#  ('Marlo Zschoche',),
#  ('Bernt Erie',),
#  ('Hirochika Piancastelli',),
#  ('Heng Kilgour',),
#  ('Nikolaos Leaver',),
#  ('Dzung Holburn',),
#  ('Prodip Schusler',),
#  ('Aksel Alencar',),
#  ('Hsiangchu Molenkamp',),
#  ('Rasiah Deyuan',),
#  ('Subbu Riexinger',),
#  ('Christfried Apsitis',),
#  ('Maris Angelopoulos',),
#  ('Christoper Schwaller',),
#  ('Arie Birge',),
#  ('Mototsugu Beilner',),
#  ('Mechthild Miyakawa',),
#  ('Uinam Stasinski',),
#  ('Guenter Ravishankar',),
#  ('Isamu Dahlbom',),
#  ('Kankanahalli Hinsberger',),
#  ('Bernardo Rouquie',),
#  ('Arunachalam Badr',),
#  ('Masali Czap',),
#  ('Roded Facello',),
#  ('Serenella Kawashima',),
#  ('Remko Shigei',),
#  ('Kasturi Bellmore',),
#  ('Arto Binkley',),
#  ('Masanao Bain',),
#  ('Snehasis Dymetman',),
#  ('Falguni Erie',),
#  ('Toshimori Bahi',),
#  ('Goa Rothe',),
#  ('Jeong Sadowsky',),
#  ('Heon Ranai',),
#  ('Teunis Liedekerke',),
#  ('Djelloul Laventhal',),
#  ('Wilmer Greenaway',),
#  ('Stella Hiroyama',),
#  ('Dinah Syrzycki',),
#  ('Uwe Garnier',),
#  ('Arra Ratnakar',),
#  ('Aamod Radwan',),
#  ('Pradeep Kaminger',),
#  ('Mahendra Picco',),
#  ('Oksana Brodie',),
#  ('Kristen Kavvadias',),
#  ('Tadahiko Strehl',),
#  ('Erzsebet Ohori',),
#  ('Phule Hammerschmidt',),
#  ('Moto Kusakari',),
#  ('Satyanarayana Cochrane',),
#  ('Vasilis Standera',),
#  ('Hausi Sidhu',),
#  ('Qunsheng Tagansky',),
#  ('Heekeun Sambasivam',),
#  ('Irene Munck',),
#  ('Seshu Sidou',),
#  ('Shalesh dAstous',),
#  ('Toshiki Muniz',),
#  ('Nakhoon Dengi',),
#  ('Rosine Granlund',),
#  ('Morrie Piazza',),
#  ('Hyuckchul Gini',),
#  ('Hatim Koshiba',),
#  ('Qunsheng Toyoshima',),
#  ('Clyde Fandrianto',),
#  ('Ioana Kirkerud',),
#  ('Anneli Frijda',),
#  ('Hongzue Heijenga',),
#  ('Willard Rosin',),
#  ('Dante Kalafatis',),
#  ('Fai Bale',),
#  ('Marl Grospietsch',),
#  ('Takahira Lichtner',),
#  ('Mikhail Rosis',),
#  ('Alejandro Kamble',),
#  ('Jiong Parfitt',),
#  ('Shirish Dredge',),
#  ('Leucio Aumann',),
#  ('Feiyu Luft',),
#  ('Khatoun Imataki',),
#  ('Eishiro Miyakawa',),
#  ('Parto Wrigley',),
#  ('Hironoby Kaiser',),
#  ('Make Peir',),
#  ('Wanqing Bratten',),
#  ('Hongzue Akaboshi',),
#  ('Jiann Hainaut',),
#  ('Yagil DasSarma',),
#  ('Shawna Meriste',),
#  ('Takahiro Deverell',),
#  ('Sibyl Rahier',),
#  ('Irena Reutenauer',),
#  ('Shooichi Escriba',),
#  ('Guenter Marchegay',),
#  ('Ortrud Nitto',),
#  ('Eckart Barriga',),
#  ('Volkmar Ebeling',),
#  ('Atreyi Mungall',),
#  ('Prodip Rosti',),
#  ('Hilary Budinsky',),
#  ('Sigeru Wynblatt',),
#  ('Ulf Siepmann',),
#  ('Martijn Kaiser',),
#  ('Mario Straney',),
#  ('Takahito Gecsei',),
#  ('Lidong Klerer',),
#  ('Masoud Fabrizio',),
#  ('Danel Impagliazzo',),
#  ('Yinlin Alpin',),
#  ('Mark Coorg',),
#  ('Uli Keustermans',),
#  ('Bingning Bakhtari',),
#  ('Candida Porotnikoff',),
#  ('Maria Bauknecht',),
#  ('Kaijung Riesenhuber',),
#  ('Divine Marzano',),
#  ('Greger Rubsam',),
#  ('Dante Cronin',),
#  ('Babette Straney',),
#  ('Sashi Osgood',),
#  ('Arunas Luce',),
#  ('Khosrow Sudbeck',),
#  ('Cathie Brlek',),
#  ('Martien Improta',),
#  ('Ferdinand Chenney',),
#  ('Patricio Bugrara',),
#  ('Hisao Tiemann',),
#  ('Reuven Dengi',),
#  ('Dzung Peltason',),
#  ('Marsha Tagansky',),
#  ('Yahiko Lammel',),
#  ('Narain Reeker',),
#  ('Evgueni Srimani',),
#  ('Jolita Jarecki',),
#  ('Akeel Narahara',),
#  ('Adel Perfilyeva',),
#  ('Volkmar Unno',),
#  ('Shichao Litvinov',),
#  ('Kazuhira Rosis',),
#  ('Junichi Kavanagh',),
#  ('Ebru Chepyzhov',),
#  ('Ronghao Yavatkar',),
#  ('Phule Oxenboll',),
#  ('Aleksandar Sudkamp',),
#  ('Khun Harbusch',),
#  ('Bodh Ranta',),
#  ('Werner Hasham',),
#  ('Tsvetan Matzel',),
#  ('Wonhee Badr',),
#  ('Sverrir Streng',),
#  ('Stepehn Hardjono',),
#  ('Oddvar Schlenzig',),
#  ('Gina Engelmann',),
#  ('Ennio Trogemann',),
#  ('Shushma VanScheik',),
#  ('Gal Karcich',),
#  ('Sumali Schlenzig',),
#  ('Ung Zaiane',),
#  ('Mang Maginnis',),
#  ('Claudi Shackel',),
#  ('Jiakeng Himler',),
#  ('Dipayan Suomi',),
#  ('Yoshimitsu Shobatake',),
#  ('Munehiko Ananiadou',),
#  ('Peternela Iwayama',),
#  ('Jouko Yamaashi',),
#  ('Salvador Lodder',),
#  ('Przemyslawa Oskamp',),
#  ('Kenton Garnham',),
#  ('Mario Rodite',),
#  ('Kokou Iisaka',),
#  ('Guoxiang Trogemann',),
#  ('Maik Ushiama',),
#  ('Duro Coney',),
#  ('Make Baba',),
#  ('Yongmao Pintelas',),
#  ('Goa Pleszkun',),
#  ('Zhiwei Anick',),
#  ('Nirmal Varley',),
#  ('Teruyuki Sundgren',),
#  ('Amstein Kossowski',),
#  ('Perla Middleton',),
#  ('Mihalis Heering',),
#  ('Elvia Homond',),
#  ('Huiqun Vuskovic',),
#  ('Garnik Narahari',),
#  ('Lobel Kumaresan',),
#  ('Maris Haraldson',),
#  ('Yakkov Servieres',),
#  ('Anyuan Zhiwei',),
#  ('Gretta Baig',),
#  ('Pramod Rabehasaina',),
#  ('Valter Cappelletti',),
#  ('Maik Luft',),
#  ('Vojin Narwekar',),
#  ('Susuma Larfeldt',),
#  ('Yonghoan Marshall',),
#  ('Dannz Pell',),
#  ('Xiong Varker',),
#  ('Isamu Auria',),
#  ('Kazuhisa Kroll',),
#  ('Kasidit Belinskaya',),
#  ('Kotesh Liedekerke',),
#  ('Abdelwaheb Riesenhuber',),
#  ('Keung Slobodova',),
#  ('Khoa Marrevee',),
#  ('Udi Gihr',),
#  ('Yuichiro Schicker',),
#  ('Tomofumi McClure',),
#  ('Raimond Kirkerud',),
#  ('Xiadong Luga',),
#  ('Tiina Speek',),
#  ('Marin Lanphier',),
#  ('Yonghoan Alencar',),
#  ('Jenwei Ecklund',),
#  ('Kwangsub Setia',),
#  ('Marke Cesareni',),
#  ('Malu Skafidas',),
#  ('Shigehiro Cincotta',),
#  ('Yuchang Lunt',),
#  ('Kwangho Theuretzbacher',),
#  ('Tetsushi Barvinok',),
#  ('Koichi Lakshmanan',),
#  ('Ymte Yetto',),
#  ('Boriana Coors',),
#  ('Oguz Gimbel',),
#  ('Mary Wossner',),
#  ('Mohamadou Smailagic',),
#  ('Dinah Bahl',),
#  ('Shalesh Stroustrup',),
#  ('Yechiam Sambasivam',),
#  ('Stella Benzmuller',),
#  ('Przemyslawa Falby',),
#  ('Yucel Reinhard',),
#  ('Martins Barriga',),
#  ('Godehard Eiter',),
#  ('Yannis Couchot',),
#  ('Lein Lichtman',),
#  ('Ishfaq Krzyzanowski',),
#  ('Hauke dAstous',),
#  ('Nechama Schapiro',),
#  ('Snehasis Brobst',),
#  ('Ramalingam Gunderson',),
#  ('Beshir Kisuki',),
#  ('Manton Leuchs',),
#  ('Jeong Rijsenbrij',),
#  ('Kazuhito Shiratori',),
#  ('Rajmohan Wallrath',),
#  ('Dines Gerlach',),
#  ('Vitaly Picci',),
#  ('JoAnna Taubman',),
#  ('Sashi Karlin',),
#  ('Hisao Famili',),
#  ('Arumugam Comellas',),
#  ('Yinlin Esteva',),
#  ('Serge Joslin',),
#  ('Shuky Pearson',),
#  ('Mohit Spelt',),
#  ('Jianhao Thisen',),
#  ('Yishay Harnett',),
#  ('Jianhui Zuberek',),
#  ('Dietrich Journel',),
#  ('Gao Poulakidas',),
#  ('Sreenivas Bashian',),
#  ('Alassane Morrin',),
#  ('Fun Varman',),
#  ('Cordelia Axelband',),
#  ('Tetsushi Speel',),
#  ('Salvador Olano',),
#  ('Theirry Yeung',),
#  ('Xiaoqiu Krychniak',),
#  ('Ennio Schmiedel',),
#  ('Shigeaki Shanbhogue',),
#  ('Aiman Stentiford',),
#  ('Christoper Rehfuss',),
#  ('Odinaldo Prochazka',),
#  ('Shmuel Juneja',),
#  ('Prasadram Stille',),
#  ('Mana Papastamatiou',),
#  ('Sajjad Willoner',),
#  ('Kirk Vuskovic',),
#  ('Behnaam Srimani',),
#  ('Shigeo Dulay',),
#  ('Subbu Sanella',),
#  ('Yongqiao Kalloufi',),
#  ('Hidde Hettesheimer',),
#  ('Almudena Alvarado',),
#  ('Falguni Kenevan',),
#  ('Kiyokazu Whitcomb',),
#  ('Giri Undy',),
#  ('Sanjit Coors',),
#  ('Lucien Schaad',),
#  ('Margo Gronowski',),
#  ('Seshu Crelier',),
#  ('Emran Rettelbach',),
#  ('Barton Usdin',),
#  ('Douadi Wossner',),
#  ('Wayne Restivo',),
#  ('Susanna Brizzi',),
#  ('Moti Wixon',),
#  ('Toshiki Marakhovsky',),
#  ('Rosalyn Hambrick',),
#  ('Adhemar Talmor',),
#  ('Janche Zhang',),
#  ('Irena Roccetti',),
#  ('Karsten Blokdijk',),
#  ('Gil Peroz',),
#  ('Inderjeet Jansen',),
#  ('Gila Ozeri',),
#  ('Keung Delgrande',),
#  ('Tommaso Marwedel',),
#  ('Hidekazu Angel',),
#  ('Ranga Yeung',),
#  ('Vivian Kusakabe',),
#  ('Marit Veeraraghavan',),
#  ('Hinrich Siepmann',),
#  ('Turgut Narlikar',),
#  ('Aleksander Danlos',),
#  ('Sham Gyorkos',),
#  ('Leszek Petereit',),
#  ('Danil Deverell',),
#  ('Shigeu Itzfeldt',),
#  ('Krisda Krogh',),
#  ('Lalit Francisci',),
#  ('Bezalel Katzenelson',),
#  ('Inderjeet Chaudhuri',),
#  ('Yoshimitsu Velardi',),
#  ('Sorina Herber',),
#  ('Nahid Chepyzhov',),
#  ('Toney Angiulli',),
#  ('Saeko Porotnikoff',),
#  ('Heejo Frolund',),
#  ('Jenwei Borovoy',),
#  ('Pramod Erol',),
#  ('Anneke Meszaros',),
#  ('Guozhong Zucker',),
#  ('Hirochika Narlikar',),
#  ('Slavian Keirsey',),
#  ('Pranas Benaini',),
#  ('Fumiyo Esposito',),
#  ('Uri Chorvat',),
#  ('Tesuro Bahk',),
#  ('Marlo Ratnaker',),
#  ('Vitali Welham',),
#  ('Hongzhu Chepyzhov',),
#  ('Zijian Maginnis',),
#  ('Danai Chachaty',),
#  ('Otmar Feinberg',),
#  ('Nahla Castellani',),
#  ('Remko Dalton',),
#  ('Sanjay Litzkow',),
#  ('Juichirou Kitsuregawa',),
#  ('Junsik Rijckaert',),
#  ('Dinah Shackel',),
#  ('Jouko Kolinko',),
#  ('Ottavia Giarratana',),
#  ('Arto Serra',),
#  ('Teunis Noriega',),
#  ('Xumin Peck',),
#  ('Qingxiang Snyers',),
#  ('Zhonghua Reeker',),
#  ('Makato Cusworth',),
#  ('Maren Granlund',),
#  ('Yurij Iisaka',),
#  ('Shunichi McAffer',),
#  ('Parviz Rebaine',),
#  ('Bluma Zeilberger',),
#  ('Hyuckchul Casperson',),
#  ('Abdelaziz Bisiani',),
#  ('Ymte Waschkowski',),
#  ('Valeri Danley',),
#  ('Alejandra Perng',),
#  ('Chriss Gide',),
#  ('Neven Brender',),
#  ('Kish Honglei',),
#  ('Florina Garnier',),
#  ('Bedir Haumacher',),
#  ('Guiseppe Stranks',),
#  ('Aimee Tokunaga',),
#  ('Zongyan Cusworth',),
#  ('Avishai Azadmanesh',),
#  ('Leon Kaiser',),
#  ('Xiaopeng Lanphier',),
#  ('Satoru Otillio',),
#  ('Matt Jumpertz',),
#  ('Denny Setia',),
#  ('Larisa Bage',),
#  ('Berhard Daescu',),
#  ('Rildo Straney',),
#  ('Zorica Acton',),
#  ('Unal Fendler',),
#  ('Bluma Hiltgen',),
#  ('Barton Engberts',),
#  ('Hatim Deverell',),
#  ('Angel Mondadori',),
#  ('Hyuncheol Zolotykh',),
#  ('Bader Szemeredi',),
#  ('Giri Baumann',),
#  ('Yolla Kropatsch',),
#  ('Hironobu Wynblatt',),
#  ('Gonzalo Eldridge',),
#  ('Moty Trystram',),
#  ('Aral Erman',),
#  ('Jiafu Mateescu',),
#  ('Sorina Kermarrec',),
#  ('Arvind DuBourdieux',),
#  ('Uma Koprowski',),
#  ('Jagoda Naumovich',),
#  ('Aran Sadowsky',),
#  ('Goa Poehlman',),
#  ('Aiman Constantine',),
#  ('Serap Tasistro',),
#  ('Adib Rullman',),
#  ('Guenter Karunanithi',),
#  ('Odinaldo Kruskal',),
#  ('Bernd Redmiles',),
#  ('Dung Gornas',),
#  ('Eckart Harnett',),
#  ('Aluzio Narlikar',),
#  ('Garnet Isard',),
#  ('Zita Minakawa',),
#  ('Saeed Kitai',),
#  ('Ugo Maliniak',),
#  ('Percy Lorho',),
#  ('Mohit Janetzko',),
#  ('Fumitaka Peak',),
#  ('Morris Andreotta',),
#  ('Sangeeta Rodham',),
#  ('Sachar Erdi',),
#  ('Morrie Gewali',),
#  ('Gurbir Hellwagner',),
#  ('Vincent Schwartzbauer',),
#  ('Rosita Oppitz',),
#  ('Gor Iacovou',),
#  ('Suzette Sadowski',),
#  ('Sven Huttel',),
#  ('Shim Wiegley',),
#  ('Kiyomitsu Peltason',),
#  ('Yaghout Syang',),
#  ('Poorav Ranze',),
#  ('Kolar Usery',),
#  ('Falguni Khalid',),
#  ('Yuchang Francisci',),
#  ('King Brendel',),
#  ('Roddy Demeyer',),
#  ('Jordanka Ushiama',),
#  ('Byong Conde',),
#  ('Pradeep Harbusch',),
#  ('Chenyi Feinberg',),
#  ('Odysseas Ressouche',),
#  ('Paddy Brizzi',),
#  ('Florina Simkin',),
#  ('Fumiyo Boyle',),
#  ('JiYoung Chenney',),
#  ('Phillip Dratva',),
#  ('Sumali Liedekerke',),
#  ('Lech Himler',),
#  ('Giap Bolsens',),
#  ('Yunming Beetstra',),
#  ('Goetz Norsworthy',),
#  ('Nathalie Standera',),
#  ('Monique Doering',),
#  ('Ishfaq Candan',),
#  ('Vishv Bouloucos',),
#  ('Bedir Perry',),
#  ('Guiseppe Kleiser',),
#  ('Munehiro Dayana',),
#  ('Avishai Bahr',),
#  ('Jacqueline Masand',),
#  ('Xiaoheng Sluis',),
#  ('Mahmut Skafidas',),
#  ('Mizuhito Kemmerer',),
#  ('Selwyn Merey',),
#  ('Mori Yavatkar',),
#  ('Goncalo Staudhammer',),
#  ('Patricio Leuchs',),
#  ('Kish Perna',),
#  ('Moty Kenevan',),
#  ('Weijing Bottner',),
#  ('Keiichiro Marzano',),
#  ('Patricia dAstous',),
#  ('Shiv Neimat',),
#  ('Frazer Ullian',),
#  ('Aruna Journel',),
#  ('Yurij Schonegge',),
#  ('Tadahiko Sgarro',),
#  ('Chinya Birdsall',),
#  ('Oksana Roisin',),
#  ('Teunis Berztiss',),
#  ('Supot Naudin',),
#  ('Khoa Rousseau',),
#  ('Goetz Hiyoshi',),
#  ('Elliott Bednarek',),
#  ('Gad Griswold',),
#  ('Yuchang Matzke',),
#  ('Uinam Zschoche',),
#  ('Masato Setlzner',),
#  ('Katsuyuki Velasco',),
#  ('Terresa Benantar',),
#  ('Kerhong Bernick',),
#  ('Giap Matzel',),
#  ('Munehiro Zallocco',),
#  ('Chenxi Leijenhorst',),
#  ('Shim Feldhoffer',),
#  ('Lijie Lunn',),
#  ('Ashish Fortenbacher',),
#  ('Berthier Menhoudj',),
#  ('Shalesh Shumilov',),
#  ('Nidapan Dymetman',),
#  ('Renny Pramanik',),
#  ('Morris Caine',),
#  ('Uri Rullman',),
#  ('Huan Monarch',),
#  ('Pascal Sooriamurthi',),
#  ('Baocai Pena',),
#  ('Irena Schurmann',),
#  ('Masaru Passino',),
#  ('Arfst Mikschl',),
#  ('Kirk Kalsbeek',),
#  ('Fan Fairtlough',),
#  ('Arnd Anandan',),
#  ('Willard Danley',),
#  ('Godehard Gammage',),
#  ('Alper Narahara',),
#  ('Fen Fiebach',),
#  ('Toong Driscoll',),
#  ('Hidde Bergere',),
#  ('Krisda Gecseg',),
#  ('Huiqun Rajcani',),
#  ('Tomoyuki Kermarrec',),
#  ('Jianhua Leivant',),
#  ('Chuanti Karlin',),
#  ('Deniz Ramras',),
#  ('Gurbir Katiyar',),
#  ('Mohammad Koshino',),
#  ('Pranav Lieberherr',),
#  ('Berni Sanella',),
#  ('Honesty Smeets',),
#  ('Dipayan Koprowski',),
#  ('Hidde Tasistro',),
#  ('Tokuyasu Serre',),
#  ('Theirry Danley',),
#  ('Fen Bratsberg',),
#  ('Makato Mayerwieser',),
#  ('Florina Schapire',),
#  ('Piyawadee Copas',),
#  ('Hercules Munck',),
#  ('Yoshinari Kalloufi',),
#  ('Jagoda Nannarelli',),
#  ('Kwangho Reinhart',),
#  ('Sreenivas Peck',),
#  ('Fusako Stenning',),
#  ('Kenroku Gonthier',),
#  ('King Bernini',),
#  ('Gino Werthner',),
#  ('Howell Baek',),
#  ('Zhenbing Kadhim',),
#  ('Byong Bhattacharjee',),
#  ('Elliott Spieker',),
#  ('Danco Etalle',),
#  ('Fayez Yeung',),
#  ('Billur Gyorkos',),
#  ('Houman Unno',),
#  ('Guangming Jonsson',),
#  ('Shahid Leppanen',),
#  ('Aram Gilg',),
#  ('Karoline Speel',),
#  ('Sukumar Wegerle',),
#  ('Mahmut Borstler',),
#  ('Filipp Suri',),
#  ('Vincent Papastamatiou',),
#  ('Subir Biron',),
#  ('Lakshmi Deville',),
#  ('Muzhong Chleq',),
#  ('Weiye Nitsche',),
#  ('Katsuo Miake',),
#  ('Fun Heuser',),
#  ('Shimshon Champarnaud',),
#  ('Teunis Kleiser',),
#  ('Rayond Cronau',),
#  ('Sushant Begiun',),
#  ('Lunjin DeMori',),
#  ('Kwangho Dredge',),
#  ('Cheong Coors',),
#  ('Ramzi Furudate',),
#  ('Susanne Jiang',),
#  ('Kazunori Vieth',),
#  ('Danil Kropatsch',),
#  ('Suebskul Srimani',),
#  ('Vishwani Petersohn',),
#  ('Adil Taubenfeld',),
#  ('Arno Kumaresan',),
#  ('Munenori Markovitch',),
#  ('Valery Rousseau',),
#  ('Ferdinand Prenel',),
#  ('Chrisa Narahara',),
#  ('Inderjeet Perly',),
#  ('Visit Nyanchama',),
#  ('Debatosh Colorni',),
#  ('Jianhui Aloia',),
#  ('Munehiro Carrere',),
#  ('JiYoung Luks',),
#  ('Rajmohan Koblick',),
#  ('Georgi Atchley',),
#  ('Arco Jervis',),
#  ('Shay Casley',),
#  ('Oscal Fasbender',),
#  ('Narain Thummel',),
#  ('Mizuhito Prochazka',),
#  ('Valery Skafidas',),
#  ('Make Spataro',),
#  ('Tesuya Slaats',),
#  ('Susumu Reghbati',),
#  ('Reinhard Lindenbaum',),
#  ('Ronghao Narahara',),
#  ('Mara Bahi',),
#  ('Kyoichi Wossner',),
#  ('Younwoo Maquelin',),
#  ('Hironoby Atchley',),
#  ('Heng Waterhouse',),
#  ('Leni Eppinger',),
#  ('Gal Scallan',),
#  ('Udaiprakash Schmezko',),
#  ('Sumali Arlazarov',),
#  ('Arch Minakawa',),
#  ('Abdulla Beutelspacher',),
#  ('Avishai Picci',),
#  ('Juyoung Seghrouchni',),
#  ('Bartek Strooper',),
#  ('Morris Famili',),
#  ('Mountaz Schicker',),
#  ('Anyuan Nanard',),
#  ('Shaowei Iisaku',),
#  ('Matk Akazan',),
#  ('Aleksander Fioravanti',),
#  ('Katsuyuki Norsworthy',),
#  ('Toshimitsu Larfeldt',),
#  ('Berna Skafidas',),
#  ('Remko Zyda',),
#  ('Kazuhiro Kushnir',),
#  ('Shaz Kabayashi',),
#  ('Gor Usery',),
#  ('Shigehito Brodie',),
#  ('Shigeichiro Wroclawski',),
#  ('Sushant Staylopatis',),
#  ('Marco Iisaku',),
#  ('Inderjeet Bharadwaj',),
#  ('Jahangir Laventhal',),
#  ('Ranga Burnard',),
#  ('Urs Danley',),
#  ('Arno Picel',),
#  ('Duke Schnabel',),
#  ('Huican Katalagarianos',),
#  ('Kerryn Vigier',),
#  ('Billur Braunschweig',),
#  ('Weiwu Choobineh',),
#  ('Naraig Kugler',),
#  ('Hatsukazu Swist',),
#  ('Takushi Bolsens',),
#  ('Eckart Braunschweig',),
#  ('Danel Pardalos',),
#  ('Eran Adachi',),
#  ('Lakshmi Kolinko',),
#  ('Premal Noriega',),
#  ('Gen Tiemann',),
#  ('Isamu Vadhan',),
#  ('Fumiko Asser',),
#  ('Valdiodio Raczkowsky',),
#  ('Muneo Papsdorf',),
#  ('Peternela Birnbaum',),
#  ('Hitomi Valette',),
#  ('Toong Murrill',),
#  ('Huiqun Bellone',),
#  ('Elrique Raney',),
#  ('Filipp Munawer',),
#  ('Sugwoo Dulin',),
#  ('Yishay Decleir',),
#  ('Somnath Parascandalo',),
#  ('Pranjal Billawala',),
#  ('Chiradeep Furedi',),
#  ('Masako Schiper',),
#  ('Flemming Baezner',),
#  ('Chinya Deyuan',),
#  ('Sumali Candan',),
#  ('Shin Foote',),
#  ('Munehiro Aingworth',),
#  ('Zhensheng Juneja',),
#  ('Arve Erde',),
#  ('Divine Aingworth',),
#  ('Chenye Hertweck',),
#  ('Matk Rahimi',),
#  ('Alselm Parascandalo',),
#  ('Marlo Kandlur',),
#  ('Insup Benveniste',),
#  ('Alain Bonifati',),
#  ...]

# %%
# Mostrar os 10 salarios máis altos
# %%sql
SELECT salary
FROM salaries
ORDER BY salary DESC
LIMIT 10
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 10 rows affected.
# [(158220,),
#  (157821,),
#  (156286,),
#  (155709,),
#  (155513,),
#  (155377,),
#  (155190,),
#  (154888,),
#  (154885,),
#  (154459,)]

# %%
# Mostrar o salario máximo, o mínimo e a media.
# %%sql
SELECT
    MAX(salary),
    MIN(salary),
    AVG(salary)
FROM salaries
# Out:
#  * mysql+pymysql://miguel:***@localhost:3306/employees
# 1 rows affected.
# [(158220, 38623, Decimal('63810.7448'))]

# %%
# assign to variable (single-line)
top_10_salaries = %sql SELECT salary FROM salaries ORDER BY salary DESC LIMIT 10

# construct Pandas DataFrame
df = top_10_salaries.DataFrame()

# %%
# assign to variable (multi-line)
# %%sql top_10_salaries <<
SELECT salary
FROM salaries
ORDER BY salary DESC
LIMIT 10

# construct Pandas DataFrame
df = top_10_salaries.DataFrame()

# %%
# Enlaces de referencia
# https://python.plainenglish.io/how-to-run-and-analyze-sql-queries-with-pandas-in-jupyter-7f02503cf46
# https://nbviewer.jupyter.org/github/corralm/medium-posts/blob/master/SQL_Jupyter_Pandas.ipynb
